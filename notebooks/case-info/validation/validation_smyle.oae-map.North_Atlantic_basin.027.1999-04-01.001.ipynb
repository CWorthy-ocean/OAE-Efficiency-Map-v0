# %%
import xarray as xr
import matplotlib.pyplot as plt
import validate_case

# %%
case = "smyle.control.perlmutter.004"

# %%
# Parameters
case = "smyle.oae-map.North_Atlantic_basin.027.1999-04-01.001"

# %%
# %%time
ds_o = xr.open_zarr(validate_case.zarr_validation_data(case)).compute()
ds_o
# Out:
# CPU times: user 389 ms, sys: 335 ms, total: 724 ms
# Wall time: 856 ms
# <xarray.Dataset> Size: 987kB
# Dimensions:           (nlat: 384, nlon: 320, time: 180)
# Coordinates:
#     TLAT              float64 8B -79.22
#     TLONG             float64 8B 320.6
#     ULAT              float64 8B -78.95
#     ULONG             float64 8B 321.1
#   * time              (time) object 1kB 0347-04-30 00:00:00 ... 0362-03-31 00...
#     z_t               float32 4B 500.0
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     ALK_ALT_CO2_diff  (nlat, nlon) float32 492kB nan nan nan nan ... nan nan nan
#     ALK_ALT_CO2_rmse  (time) float64 1kB 0.01155 0.03777 ... 0.2037 0.1304
#     DIC_ALT_CO2_diff  (nlat, nlon) float32 492kB nan nan nan nan ... nan nan nan
#     DIC_ALT_CO2_rmse  (time) float64 1kB 0.01624 0.0522 0.08647 ... 0.2257 0.155

# %%
variables = [v[:-5] for v in ds_o.variables if "_rmse" in v]

# %%
plt.rcParams.update({'figure.max_open_warning': 0})

for v in variables:
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))
    ds_o[f"{v}_rmse"].plot(ax=axs[0])   
    ds_o[f"{v}_diff"].plot(ax=axs[1])
    plt.suptitle(v, fontweight="bold")
